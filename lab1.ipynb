# %% [markdown]
# # Preparacion Inicial

# %%
# %pip install scikit-learn-extra
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_samples, silhouette_score

from scipy.cluster.hierarchy import dendrogram

from sklearn_extra.cluster import KMedoids

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)

# %%
info = pd.read_csv('./data/202320_Laboratorio 1 - Agrupación_data_MovieAlpes_data.csv', index_col=0, sep=';')

# %%
info.shape
# Out:
# (7471, 17)

# %%
info.sample(5)
# Out:
#       index      tconst titleType                      originalTitle  isAdult  \
# #
# 1083   1749   tt0407362  tvSeries               Battlestar Galactica      0.0
# 226     613   tt3463250     movie                        A Despedida      0.0
# 4494   5970   tt4592410  tvSeries                       The Get Down      0.0
# 2393   3385  tt13075042  tvSeries  Pretty Little Liars: Original Sin      0.0
# 846    1450   tt0329111     movie                       Les Ã©garÃ©s      0.0
#
#       startYear runtimeMinutes  averageRating  numVotes  ordering region  \
# #
# 1083     2004.0             44            8.7  170677.0      24.0     IN
# 226      2014.0             90            7.3     129.0       1.0     US
# 4494     2016.0             52            8.2   23190.0      14.0     IN
# 2393     2022.0             \N            7.0    7234.0       1.0     IN
# 846      2003.0             95            6.5    3336.0       6.0     IN
#
# ...

# %% [markdown]
# ## Calidad y limpieza

# %%
(info.isnull().sum() / info.shape[0]).sort_values(ascending = False)
# Out:
# numVotes           0.000134
# ordering           0.000134
# main_genre         0.000134
# isOriginalTitle    0.000134
# attributes         0.000134
# types              0.000134
# language           0.000134
# region             0.000134
# secondary_genre    0.000134
# averageRating      0.000134
# runtimeMinutes     0.000134
# startYear          0.000134
# isAdult            0.000134
# tconst             0.000000
# originalTitle      0.000000
# titleType          0.000000
# index              0.000000
# dtype: float64

# %%
info.loc[info.duplicated(subset = info.columns[1:], keep = False)].sort_values(by = 'originalTitle').head(9)
# Out:
#       index      tconst titleType  \
# #
# 6403   8429   tt0395843  tvSeries
# 6403   8429   tt0395843  tvSeries
# 88      299  tt12443930     MOVIE
# 88      299  tt12443930     MOVIE
# 6402   8424   tt0390538     movie
# 6402   8424   tt0390538     movie
#
#                                     originalTitle  isAdult  startYear  \
# #
# 6403                                      CSI: NY      0.0     2004.0
# 6403                                      CSI: NY      0.0     2004.0
# 88    Les choses qu'on dit, les choses qu'on fait      0.0     2020.0
# 88    Les choses qu'on dit, les choses qu'on fait      0.0     2020.0
# 6402                                    Tarnation      0.0     2003.0
# 6402                                    Tarnation      0.0     2003.0
#
#      runtimeMinutes  averageRating  numVotes  ordering region language  \
# #
# 6403             43            6.9   48364.0      31.0     CA       en
# 6403             43            6.9   48364.0      31.0     CA       en
# ...

# %%
print('Total de peliculas repetidas:', info.loc[info.duplicated(subset = info.columns[1:], keep = False)].shape[0])
# Out:
# Total de peliculas repetidas: 0

# %%
info.drop_duplicates(subset = info.columns[1:], inplace = True)
